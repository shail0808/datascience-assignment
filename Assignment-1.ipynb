# %% [markdown]
# # Assignment -1

# %% [markdown]
# ### Q1. In the below elements which of them are values or an expression? eg:- values can be integer or string and expressions will be mathematical operators.

# %% [markdown]
# Answer :
# - (1) Values are 'hello', -87.8,  6
# - (2) Expression are *, -, / & +

# %% [markdown]
# ### Q2. What is the difference between string and variable?

# %% [markdown]
# Answer:
# - String is value reprentating Text. Any values having quoted with single quote (') or double quote (") is string
# - Variable is name that can be referred to any value, used to assign value and save it to memory location and can be iterated any number of times to recall value stored in it

# %% [markdown]
# ### Q3. Describe three different data types.

# %% [markdown]
# Answer:
# Three Types of Datatypes can be defined as
# - Integer
# - Flot
# - String

# %% [markdown]
# ##### Q4. What is an expression made up of? What do all expressions do?

# %% [markdown]
# Answer :
# Python Expressions are mainly of three types refer as Opertors, Literals and identifiers.
#
# - Operator can be used for assigning values to variables, for comparision and for doing many methamatical and logical operation
# - Identifier is name that is used to define function, class, object, variable modules
# - Literal are string literals, byte literals, integer literal, floating point literals and imaginary literals

# %% [markdown]
# ##### Q5. This assignment statements, like spam = 10. What is the difference between an expression and a statement?

# %% [markdown]
# Answer:
# - Here, '=' sign represents as assignment operator which is an expression in python and 'Spam = 10' represent the complete statement that variable 'spam' has been assigned value which is 10.

# %% [markdown]
# ##### Q6. After running the following code, what does the variable bacon contain?
# bacon = 22,
# bacon + 1

# %%
bacon = 22
print('Answer of Q6 (bacon+1) is ', bacon+1)
# Out:
# Answer of Q6 (bacon+1) is  23

# %% [markdown]
# ##### 7. What should the values of the following two terms be?

# %% [markdown]
# 'spam' + 'spamspam'
# 'spam' *3

# %%
print('Anwer:')
print('value of term spam+spamspam is:', 'spam' + 'spamspam')
print('value of term spam*3 is:', 'spam' * 3)
# Out:
# Anwer:
# value of term spam+spamspam is: spamspamspam
# value of term spam*3 is: spamspamspam

# %% [markdown]
# ##### Q8. Why is eggs a valid variable name while 100 is invalid?

# %% [markdown]
# Answer: Python supports varialbe names starting with alphabates, underscore(_) and combination of it but does not support number as variable

# %% [markdown]
# ##### Q9. What three functions can be used to get the integer, floating-point number, or string version of a value?

# %%
a = 20
b = float(a)
c = str(a)
print('Function Int can be used to get Integer value of a:', int(a), type(a))
print('Function float can be used to get float value of a:', float(b),type(b))
print('Function str can be used to get str value of a:', str(c),type(c))
# Out:
# Function Int can be used to get Integer value of a: 20 <class 'int'>
# Function float can be used to get float value of a: 20.0 <class 'float'>
# Function str can be used to get str value of a: 20 <class 'str'>

# %% [markdown]
# ##### Q10. Why does this expression cause an error? How can you fix it?
# 'I have eaten ' + 99 + ' burritos.'

# %% [markdown]
# Answer: Mathematical Operation (i.e. summation) between different datatype is not possible being String and Numerica values. By converting numeric value 99 in string as '99' we can do said operation (i.e. concatination) as mentioned below.

# %%
a = 99
b = str(99)    #conveting 99 into string from interger 
print('Answer to Q10:', 'I have eaten ' + b + ' burritos.')
# Out:
# Answer to Q10: I have eaten 99 burritos.
